# %%
# Load Libraries
import json
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

# Load project configuration
with open('config.json', 'r') as f:
    config = json.load(f)

with open(Path(config['paths']['data_processed']) / 'analysis_config.json', 'r') as f:
    analysis_config = json.load(f)

data_processed = Path(config['paths']['data_processed'])
figures_path = Path(config['paths']['figures'])

# Load climate data
climate_df = pd.read_csv(data_processed / 'climate_daily.csv')
climate_df['date'] = pd.to_datetime(climate_df['date'])

print(f"✓ Loaded climate data: {len(climate_df)} records")
print(f"  Date range: {climate_df['date'].min()} to {climate_df['date'].max()}")
print(f"  Neighborhoods: {climate_df['GEOID'].nunique()}")
